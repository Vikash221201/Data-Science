# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/banknote-authentication.csv')

# %%
print(data)
# Out:
#       variance      skew  curtosis  entropy  class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# variance    0
# skew        0
# curtosis    0
# entropy     0
# class       0
# dtype: int64

# %%
mean_of_data=data.curtosis.mean()

# %%
print(mean_of_data)
# Out:
# 1.3976271172667638

# %%
data.curtosis.fillna(mean_of_data)
# Out:
# 0       -2.8073
# 1       -2.4586
# 2        1.9242
# 3       -4.0112
# 4        4.5718
#          ...
# 1367    -1.4501
# 1368     6.4774
# 1369    17.5932
# 1370    12.3930
# 1371     2.6842
# Name: curtosis, Length: 1372, dtype: float64

# %%
print(data)
# Out:
#       variance      skew  curtosis  entropy  class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
data.Embarked.fillna

# %% [markdown]
# # Drop a column and print the data

# %%
data.drop('curtosis', axis=1, inplace=True)

# %%
print(data)
# Out:
#       variance      skew  entropy  class
# 0      3.62160   8.66610 -0.44699      0
# 1      4.54590   8.16740 -1.46210      0
# 2      3.86600  -2.63830  0.10645      0
# 3      3.45660   9.52280 -3.59440      0
# 4      0.32924  -4.45520 -0.98880      0
# ...        ...       ...      ...    ...
# 1367   0.40614   1.34920 -0.55949      1
# 1368  -1.38870  -4.87730  0.34179      1
# 1369  -3.75030 -13.45860 -2.77710      1
# 1370  -3.56370  -8.38270 -1.28230      1
# 1371  -2.54190  -0.65804  1.19520      1
#
# [1372 rows x 4 columns]

# %% [markdown]
# # drop a particular row

# %%
data.drop(2, axis=0, inplace=True)

# %%
print(data)
# Out:
#       variance      skew  entropy  class
# 0      3.62160   8.66610 -0.44699      0
# 1      4.54590   8.16740 -1.46210      0
# 3      3.45660   9.52280 -3.59440      0
# 4      0.32924  -4.45520 -0.98880      0
# 5      4.36840   9.67180 -3.16250      0
# ...        ...       ...      ...    ...
# 1367   0.40614   1.34920 -0.55949      1
# 1368  -1.38870  -4.87730  0.34179      1
# 1369  -3.75030 -13.45860 -2.77710      1
# 1370  -3.56370  -8.38270 -1.28230      1
# 1371  -2.54190  -0.65804  1.19520      1
#
# [1371 rows x 4 columns]

# %%
filtered_data = data[(data['class'] == 0) & (data['variance'] == 1.8993)]

# %%
print(filtered_data)
# Out:
#     variance    skew  entropy  class
# 12    1.8993  7.6625  -3.1108      0

# %%
# remember this code
''' data=pd.read_csv('filename.csv',col_names=['col1','col2'......])

# %%
count_of_class=data['class'].value_counts()

# %%
print(count_of_class)
# Out:
# class
# 0    761
# 1    610
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Get the value counts of 'class' column
class_counts = data['class'].value_counts()

# Plot the bar graph
class_counts.plot(kind='bar')

# Add title and labels
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
data['variance'].plot(kind='hist', bins=20, edgecolor='black')

# Add title and labels
plt.title('Variance Distribution')
plt.xlabel('Variance')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
data.plot(kind='hexbin', x='class', y='entropy', gridsize=10)
plt.show()

# %%
data['variance'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
